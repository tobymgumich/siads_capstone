# %%
import requests
from bs4 import BeautifulSoup, Comment
import re
import pandas as pd
import os
import json

# %% [markdown]
# ## Data Collection

# %% [markdown]
# ### Data Cleaning - helper function

# %%
def clean_text(text):
    """Clean the extracted text by removing extra spaces, unnecessary citations, and handling links properly."""
    text = re.sub(r'\s+', ' ', text).strip()
    text = re.sub(r'\[\d+\]', '', text)
    text = re.sub(r'\[([^\]]+)\]\(([^\)]+)\)\s+\1', r'[\1](\2)', text)
    text = re.sub(r'\[\]', '', text)
    text = re.sub(r'\(https://en.wikipedia.org#cite[^\)]+\)', '', text)
    text = re.sub(r'\(https://en.wikipedia.org/wiki/Wikipedia:Please_clarify\)', '', text)
    return text

# %% [markdown]
# ## Data Labelling - helper
#
# For wikilinks within a wikipage, we want to capture these titles and paths to update to our wikipages.csv

# %%
def label_linked_entities(element):
    """Extract text from an HTML element, preserving links as Markdown."""
    result = ''
    for child in element.descendants:
        if child.name == 'a':
            if 'reference' in child.get('class', []) or 'citation' in child.get('class', []):
                continue
            
            href = child.get('href')
            if href and href.startswith('/wiki/'):
                link_text = child.get_text()
                result += f"[{link_text}](https://en.wikipedia.org{href}) "
        elif child.name == 'sup':
            continue
        elif isinstance(child, str):
            result += child + ' '

    patterns = [
        r'(\[\[.*)(\]?)(\(https:\/\/en\.wikipedia\.org\/wiki\/Wikipedia\:)(\w{3,25}\)\])(?=(\s|\.|,|$))',
        r'(\[\[.*)(\]?)(\(https:\/\/en\.wikipedia\.org\/wiki\/Wikipedia\:)(Manual_of_Style\/)?(Words_to_watch|Dates_and_numbers|Citing_sources)(\#)(\w{3,25}\)\])(?=(\s|\.|,|$))',
    ]
    for pattern in patterns:
        result = re.sub(pattern, '', result)
    
    return result.strip()

# %% [markdown]
# ### Data Extraction
# The following function pulls data from our wikipages, splits it by section and sub-section using h2 and h3 headers. We then use our helper functions to clean the content (within each section) and label any identified wiki titles and paths for our wikipages.

# %%
def extract_wikipedia_contents(wiki_path, ontology_term, kb_lookup):
    """
    Extract and process content from a Wikipedia page, updating the knowledge base lookup.

    Args:
    wiki_path (str): The Wikipedia page path.
    ontology_term (str): The ontology term to associate with the Wikipedia content.
    kb_lookup (dict): The existing knowledge base lookup dictionary.

    Returns:
    tuple: (Updated kb_lookup, DataFrame of extracted content, Status message)
    """
    wiki_path = wiki_path.strip().lower()
    ontology_term = ontology_term.strip().lower()
    
    url = f"https://en.wikipedia.org/wiki/{wiki_path}"
    response = requests.get(url)
    if response.status_code != 200:
        return kb_lookup, pd.DataFrame(), f"Error: Unable to fetch the page '{wiki_path}'. Status code: {response.status_code}"

    soup = BeautifulSoup(response.text, 'html.parser')
    title = soup.find('h1', id='firstHeading').text.strip().lower()
    
    is_redirect = False
    redirect_span = soup.find('span', class_='mw-redirectedfrom')
    if redirect_span:
        canonical_link = soup.find('link', rel='canonical')
        wiki_path = canonical_link['href'].split("/wiki/")[-1].strip().lower()
        is_redirect = True
    
    if wiki_path in kb_lookup["wiki_paths"]:
        if ontology_term in kb_lookup["wiki_paths"][wiki_path]["ontology_terms"]:
            return kb_lookup, pd.DataFrame(), f"Error: Kb_lookup Entry for ontology_term '{ontology_term}' already exists in wiki_path '{wiki_path}'."
        else:
            kb_lookup["wiki_paths"][wiki_path]["ontology_terms"].append({"term": ontology_term, "redirect": is_redirect})
            return kb_lookup, pd.DataFrame(), f"Success: Kb_lookup Entry for ontology_term '{ontology_term}' has been updated under wiki_path '{wiki_path}'."
    else:
        kb_lookup["wiki_paths"][wiki_path] = {"wiki_title": title, "ontology_terms": [{"term": ontology_term, "redirect": is_redirect}]}
    
    content_div = soup.find('div', class_='mw-parser-output')
    
    for tag in content_div(['script', 'style', 'svg']):
        tag.decompose()
    
    for comment in content_div.find_all(string=lambda string: isinstance(string, Comment)): 
        comment.extract()
       
    for sup in content_div.find_all('sup'):
        sup.decompose()
    
    sections = []
    current_h2 = "Introduction"
    current_h3 = None
    current_content = ""

    for element in content_div.find_all(['h2', 'h3', 'p', 'ul', 'ol']):
        if current_h2 == "Introduction":
            if element.name == 'h2':
                if current_content.strip():
                    sections.append({
                        'wiki_path': wiki_path,
                        'title': title,
                        'h2': current_h2,
                        'h3': current_h3 if current_h3 else '',
                        'content': clean_text(current_content)
                    })
                current_h2 = element.get_text(strip=True)
                current_h3 = None
                current_content = ""
            elif element.name == 'p':
                current_content += label_linked_entities(element) + " "
        elif element.name == 'h2':
            h2_text = element.get_text(strip=True)
            if h2_text == 'References':
                break
            if current_content.strip():
                sections.append({
                    'wiki_path': wiki_path,
                    'title': title,
                    'h2': current_h2,
                    'h3': current_h3 if current_h3 else '',
                    'content': clean_text(current_content)
                })
            current_h2 = h2_text
            current_h3 = None
            current_content = ""
        elif element.name == 'h3':
            if current_h3 and current_content.strip():
                sections.append({
                    'wiki_path': wiki_path,
                    'title': title,
                    'h2': current_h2,
                    'h3': current_h3,
                    'content': clean_text(current_content)
                })
            current_h3 = element.get_text(strip=True)
            current_content = ""
        elif element.name in ['p', 'ul', 'ol']:
            current_content += label_linked_entities(element) + " "

    if current_content.strip():
        sections.append({
            'wiki_path': wiki_path,
            'title': title,
            'h2': current_h2,
            'h3': current_h3 if current_h3 else '',
            'content': clean_text(current_content)
        })

    if sections:
        return kb_lookup, pd.DataFrame(sections), f"Success: New Kb_lookup Entry added for ontology_term '{ontology_term}' and wiki_path '{wiki_path}'."
    else:
        return kb_lookup, pd.DataFrame([{
            'wiki_path': wiki_path,
            'title': title,
            'h2': 'No sections',
            'h3': '',
            'content': 'No content found or all content filtered out.'
        }]), f"Warning: New Kb_lookup Entry added for ontology_term '{ontology_term}' and wiki_path '{wiki_path}', but no content was found."

# %%
ontology_links = '../ontology_links.csv'
ontology_links_df = pd.read_csv(ontology_links)

# %%
ontology_links_df = ontology_links_df.rename(columns={'taxonomy_term': 'ontology_term'})
ontology_links_wiki = ontology_links_df.dropna(subset=['wiki_title', 'wiki_path'])
ontology_links_wiki.head()
# Out:
#                     ontology_term  \
# 1                Cluster Analysis
# 4                         Sigmoid
# 5  Generative Adversarial Network
# 6          Least-Angle Regression
# 8          Part-Of-Speech Tagging
#
#                                        term_regex  \
# 1                         cluster(\s*|\-)?analysi
# 4                                         sigmoid
# 5  generative(\s*|\-)?adversarial(\s*|\-)?network
# 6          least(\s*|\-)?angle(\s*|\-)?regression
# 8  part(\s*|\-)?of(\s*|\-)?speech(\s*|\-)?tagging
#
#                        wiki_title                       wiki_path
# 1                cluster analysis                cluster_analysis
# 4                         sigmoid                sigmoid_function
# 5  generative adversarial network  generative_adversarial_network
# 6          least-angle regression          least-angle_regression
# 8          part-of-speech tagging          part-of-speech_tagging

# %%
wiki_content_list = []
kb_lookup = {"wiki_paths": {}, "ontology_terms": {}}

for index, row in ontology_links_wiki.iterrows():
    wiki_path = row['wiki_path']
    ontology_term = row['ontology_term']
    kb_lookup = kb_lookup
    try:
        kb_lookup, df, status = extract_wikipedia_contents(wiki_path, ontology_term, kb_lookup)
        
        if status.startswith("Success: New Kb_lookup Entry added"):
            wiki_content_list.append(df)
            print(f"{status}...and successfully added new content to knowledge base")
        else:
            print(status)
    except Exception as e:
        print(f"Error processing {wiki_path}: {str(e)}")
# Out:
# Success: New Kb_lookup Entry added for ontology_term 'cluster analysis' and wiki_path 'cluster_analysis'....and successfully added new content to knowledge base
# Success: New Kb_lookup Entry added for ontology_term 'sigmoid' and wiki_path 'sigmoid_function'....and successfully added new content to knowledge base
# Success: New Kb_lookup Entry added for ontology_term 'generative adversarial network' and wiki_path 'generative_adversarial_network'....and successfully added new content to knowledge base
# Success: New Kb_lookup Entry added for ontology_term 'least-angle regression' and wiki_path 'least-angle_regression'....and successfully added new content to knowledge base
# Success: New Kb_lookup Entry added for ontology_term 'part-of-speech tagging' and wiki_path 'part-of-speech_tagging'....and successfully added new content to knowledge base
# Success: New Kb_lookup Entry added for ontology_term 'false positive' and wiki_path 'false_positives_and_false_negatives'....and successfully added new content to knowledge base
# Success: New Kb_lookup Entry added for ontology_term 'gaussian mixture models' and wiki_path 'mixture_model#gaussian_mixture_model'....and successfully added new content to knowledge base
# Success: Kb_lookup Entry for ontology_term 'least angle regression' has been updated under wiki_path 'least-angle_regression'.
# Success: New Kb_lookup Entry added for ontology_term 'retrieval augmented generation' and wiki_path 'retrieval-augmented_generation'....and successfully added new content to knowledge base
# Success: New Kb_lookup Entry added for ontology_term 'inductive logic programming' and wiki_path 'inductive_logic_programming'....and successfully added new content to knowledge base
# Success: New Kb_lookup Entry added for ontology_term 'peak signal-to-noise ratio' and wiki_path 'peak_signal-to-noise_ratio'....and successfully added new content to knowledge base
# Success: New Kb_lookup Entry added for ontology_term 'embeddings' and wiki_path 'word_embedding'....and successfully added new content to knowledge base
# Success: New Kb_lookup Entry added for ontology_term 'k-means clustering' and wiki_path 'k-means_clustering'....and successfully added new content to knowledge base
# Success: New Kb_lookup Entry added for ontology_term 'fine-tuning' and wiki_path 'fine-tuning_(deep_learning)'....and successfully added new content to knowledge base
# Error: Unable to fetch the page 'mean_absolute_percentage_error)'. Status code: 404
# Success: New Kb_lookup Entry added for ontology_term 'accuracy' and wiki_path 'accuracy_and_precision#in_binary_classification'....and successfully added new content to knowledge base
# Success: New Kb_lookup Entry added for ontology_term 'recall' and wiki_path 'precision_and_recall'....and successfully added new content to knowledge base
# Success: New Kb_lookup Entry added for ontology_term 'latent diffusion models' and wiki_path 'diffusion_model'....and successfully added new content to knowledge base
# Success: New Kb_lookup Entry added for ontology_term 'apriori algorithm' and wiki_path 'apriori_algorithm'....and successfully added new content to knowledge base
# Success: New Kb_lookup Entry added for ontology_term 'bayesian optimization' and wiki_path 'bayesian_optimization'....and successfully added new content to knowledge base
# Success: New Kb_lookup Entry added for ontology_term 'non-negative matrix factorization' and wiki_path 'non-negative_matrix_factorization'....and successfully added new content to knowledge base
# Error: Unable to fetch the page 'gaussian_naive_bayes'. Status code: 404
# Success: New Kb_lookup Entry added for ontology_term 'q-learning' and wiki_path 'q-learning'....and successfully added new content to knowledge base
# Success: New Kb_lookup Entry added for ontology_term 'cross-validation' and wiki_path 'cross-validation_(statistics)'....and successfully added new content to knowledge base
# Success: New Kb_lookup Entry added for ontology_term 'confusion matrix' and wiki_path 'confusion_matrix'....and successfully added new content to knowledge base
# Success: New Kb_lookup Entry added for ontology_term 'newton's method' and wiki_path 'newton%27s_method'....and successfully added new content to knowledge base
# Success: New Kb_lookup Entry added for ontology_term 'eclat algorithm' and wiki_path 'association_rule_learning#eclat_algorithm'....and successfully added new content to knowledge base
# Success: New Kb_lookup Entry added for ontology_term 'topic modeling' and wiki_path 'topic_model'....and successfully added new content to knowledge base
# Success: New Kb_lookup Entry added for ontology_term 'boltzmann machines' and wiki_path 'boltzmann_machine'....and successfully added new content to knowledge base
# Success: New Kb_lookup Entry added for ontology_term 'hierarchical clustering' and wiki_path 'hierarchical_clustering'....and successfully added new content to knowledge base
# Success: New Kb_lookup Entry added for ontology_term 'k-medians' and wiki_path 'k-medians_clustering'....and successfully added new content to knowledge base
# Success: New Kb_lookup Entry added for ontology_term 'probably approximately correct learning' and wiki_path 'probably_approximately_correct_learning'....and successfully added new content to knowledge base
# Success: New Kb_lookup Entry added for ontology_term 'sparse coding' and wiki_path 'neural_coding#sparse_coding'....and successfully added new content to knowledge base
# Success: New Kb_lookup Entry added for ontology_term 'convolutional neural network' and wiki_path 'convolutional_neural_network'....and successfully added new content to knowledge base
# Error: Unable to fetch the page 'fasttext'. Status code: 404
# Success: New Kb_lookup Entry added for ontology_term 'case-based reasoning' and wiki_path 'case-based_reasoning'....and successfully added new content to knowledge base
# Success: New Kb_lookup Entry added for ontology_term 'concept drift' and wiki_path 'concept_drift'....and successfully added new content to knowledge base
# Success: New Kb_lookup Entry added for ontology_term 'gradient boosting' and wiki_path 'gradient_boosting'....and successfully added new content to knowledge base
# Success: New Kb_lookup Entry added for ontology_term 'adagrad' and wiki_path 'stochastic_gradient_descent#adagrad'....and successfully added new content to knowledge base
# Success: New Kb_lookup Entry added for ontology_term 'synthetic data' and wiki_path 'synthetic_data'....and successfully added new content to knowledge base
# Success: New Kb_lookup Entry added for ontology_term 'bayesian network' and wiki_path 'bayesian_network'....and successfully added new content to knowledge base
# Success: New Kb_lookup Entry added for ontology_term 'mean squared error' and wiki_path 'mean_squared_error'....and successfully added new content to knowledge base
# Success: New Kb_lookup Entry added for ontology_term 'principal component analysis' and wiki_path 'principal_component_analysis'....and successfully added new content to knowledge base
# Warning: New Kb_lookup Entry added for ontology_term 'hidden markov models' and wiki_path 'hidden_markov_model', but no content was found.
# Success: New Kb_lookup Entry added for ontology_term 'named-entity recognition' and wiki_path 'named-entity_recognition'....and successfully added new content to knowledge base
# Success: New Kb_lookup Entry added for ontology_term 'optical flow' and wiki_path 'optical_flow'....and successfully added new content to knowledge base
# Success: New Kb_lookup Entry added for ontology_term 'autoencoder' and wiki_path 'autoencoder'....and successfully added new content to knowledge base
# Success: New Kb_lookup Entry added for ontology_term 'association rule learning' and wiki_path 'association_rule_learning'....and successfully added new content to knowledge base
# Success: New Kb_lookup Entry added for ontology_term 'ripple down rules' and wiki_path 'ripple-down_rules'....and successfully added new content to knowledge base
# Success: New Kb_lookup Entry added for ontology_term 'regression analysis' and wiki_path 'regression_analysis'....and successfully added new content to knowledge base
# Success: New Kb_lookup Entry added for ontology_term 'max pooling' and wiki_path 'convolutional_neural_network#pooling_layer'....and successfully added new content to knowledge base
# Success: New Kb_lookup Entry added for ontology_term 'stochastic gradient descent' and wiki_path 'stochastic_gradient_descent'....and successfully added new content to knowledge base
# Success: New Kb_lookup Entry added for ontology_term 'gaussian process regression' and wiki_path 'kriging'....and successfully added new content to knowledge base
# Success: New Kb_lookup Entry added for ontology_term 'gradient boosted decision tree' and wiki_path 'gradient_boosting#gradient_tree_boosting'....and successfully added new content to knowledge base
# Success: New Kb_lookup Entry added for ontology_term 'multi-class classification' and wiki_path 'multiclass_classification'....and successfully added new content to knowledge base
# Success: New Kb_lookup Entry added for ontology_term 'transfer learning' and wiki_path 'transfer_learning'....and successfully added new content to knowledge base
# Error: Unable to fetch the page 'l-bfgs'. Status code: 404
# Success: New Kb_lookup Entry added for ontology_term 'binary classification' and wiki_path 'binary_classification'....and successfully added new content to knowledge base
# Success: New Kb_lookup Entry added for ontology_term 'multivariate adaptive regression splines' and wiki_path 'multivariate_adaptive_regression_spline'....and successfully added new content to knowledge base
# Success: New Kb_lookup Entry added for ontology_term 'scaling' and wiki_path 'scaling_(geometry)'....and successfully added new content to knowledge base
# Success: New Kb_lookup Entry added for ontology_term 'hierarchical classifier' and wiki_path 'hierarchical_classification'....and successfully added new content to knowledge base
# Success: New Kb_lookup Entry added for ontology_term 'tanh' and wiki_path 'hyperbolic_functions'....and successfully added new content to knowledge base
# Success: Kb_lookup Entry for ontology_term 'word embeddings' has been updated under wiki_path 'word_embedding'.
# Success: New Kb_lookup Entry added for ontology_term 'root mean squared error' and wiki_path 'root_mean_square_deviation'....and successfully added new content to knowledge base
# Success: New Kb_lookup Entry added for ontology_term 'random search' and wiki_path 'random_search'....and successfully added new content to knowledge base
# Success: New Kb_lookup Entry added for ontology_term 'overfitting' and wiki_path 'overfitting'....and successfully added new content to knowledge base
# Success: New Kb_lookup Entry added for ontology_term 'self-supervised learning' and wiki_path 'self-supervised_learning'....and successfully added new content to knowledge base
# Success: New Kb_lookup Entry added for ontology_term 'long short-term memory' and wiki_path 'long_short-term_memory'....and successfully added new content to knowledge base

# %%
ontology_terms_available = len(ontology_links_wiki)
ontology_terms_added = sum(len(entry["ontology_terms"]) for entry in kb_lookup["wiki_paths"].values())
ontology_terms_not_added = ontology_terms_available - ontology_terms_added

print(f"Total number of ontology terms to link: {ontology_terms_available}")
print(f"Total number of ontology terms linked: {ontology_terms_added}")
print(f"Total number of ontology terms with errors: {ontology_terms_not_added}")
# Out:
# Total number of ontology terms to link: 284
# Total number of ontology terms linked: 268
# Total number of ontology terms with errors: 16

# %% [markdown]
# ## Save files

# %%
if wiki_content_list:
    wiki_content = pd.concat(wiki_content_list, ignore_index=True)
    
    print(f"Number of rows in wiki_content: {len(wiki_content)}")
    
    relative_path = '../../siads_capstone/'
    
    absolute_path = os.path.abspath(relative_path)
    
    file_name = "knowledge_base.csv"
    
    file_path = os.path.join(absolute_path, file_name)

    wiki_content.to_csv(file_path, index=False)
    print(f"wiki_content has been saved as '{file_name}' in the following directory:")
    print(absolute_path)
else:
    print("No valid DataFrames were generated. wiki_content.csv was not created.")
# Out:
# Number of rows in wiki_content: 3110
# wiki_content has been saved as 'knowledge_base.csv' in the following directory:
# /home/sagemaker-user/siads_capstone

# %%
kb_lookup
# Out:
# {'wiki_paths': {'cluster_analysis': {'wiki_title': 'cluster analysis',
#    'ontology_terms': [{'term': 'cluster analysis', 'redirect': False}]},
#   'sigmoid_function': {'wiki_title': 'sigmoid function',
#    'ontology_terms': [{'term': 'sigmoid', 'redirect': False}]},
#   'generative_adversarial_network': {'wiki_title': 'generative adversarial network',
#    'ontology_terms': [{'term': 'generative adversarial network',
#      'redirect': False}]},
#   'least-angle_regression': {'wiki_title': 'least-angle regression',
#    'ontology_terms': [{'term': 'least-angle regression', 'redirect': False},
#     {'term': 'least angle regression', 'redirect': False}]},
#   'part-of-speech_tagging': {'wiki_title': 'part-of-speech tagging',
#    'ontology_terms': [{'term': 'part-of-speech tagging', 'redirect': False}]},
#   'false_positives_and_false_negatives': {'wiki_title': 'false positives and false negatives',
#    'ontology_terms': [{'term': 'false positive', 'redirect': True}]},
#   'mixture_model#gaussian_mixture_model': {'wiki_title': 'mixture model',
#    'ontology_terms': [{'term': 'gaussian mixture models', 'redirect': True}]},
#   'retrieval-augmented_generation': {'wiki_title': 'retrieval-augmented generation',
#    'ontology_terms': [{'term': 'retrieval augmented generation',
#      'redirect': False}]},
#   'inductive_logic_programming': {'wiki_title': 'inductive logic programming',
#    'ontology_terms': [{'term': 'inductive logic programming',
#      'redirect': False}]},
#   'peak_signal-to-noise_ratio': {'wiki_title': 'peak signal-to-noise ratio',
#    'ontology_terms': [{'term': 'peak signal-to-noise ratio',
#      'redirect': False}]},
#   'word_embedding': {'wiki_title': 'word embedding',
#    'ontology_terms': [{'term': 'embeddings', 'redirect': False},
#     {'term': 'word embeddings', 'redirect': False}]},
#   'k-means_clustering': {'wiki_title': 'k-means clustering',
#    'ontology_terms': [{'term': 'k-means clustering', 'redirect': False}]},
#   'fine-tuning_(deep_learning)': {'wiki_title': 'fine-tuning (deep learning)',
#    'ontology_terms': [{'term': 'fine-tuning', 'redirect': False}]},
#   'accuracy_and_precision#in_binary_classification': {'wiki_title': 'accuracy and precision',
#    'ontology_terms': [{'term': 'accuracy', 'redirect': False}]},
#   'precision_and_recall': {'wiki_title': 'precision and recall',
#    'ontology_terms': [{'term': 'recall', 'redirect': True}]},
#   'diffusion_model': {'wiki_title': 'diffusion model',
#    'ontology_terms': [{'term': 'latent diffusion models', 'redirect': False},
#     {'term': 'diffusion models', 'redirect': False}]},
#   'apriori_algorithm': {'wiki_title': 'apriori algorithm',
#    'ontology_terms': [{'term': 'apriori algorithm', 'redirect': False}]},
#   'bayesian_optimization': {'wiki_title': 'bayesian optimization',
#    'ontology_terms': [{'term': 'bayesian optimization', 'redirect': False}]},
#   'non-negative_matrix_factorization': {'wiki_title': 'non-negative matrix factorization',
#    'ontology_terms': [{'term': 'non-negative matrix factorization',
#      'redirect': False}]},
#   'q-learning': {'wiki_title': 'q-learning',
#    'ontology_terms': [{'term': 'q-learning', 'redirect': False}]},
#   'cross-validation_(statistics)': {'wiki_title': 'cross-validation (statistics)',
#    'ontology_terms': [{'term': 'cross-validation', 'redirect': False},
#     {'term': 'k-fold', 'redirect': False}]},
#   'confusion_matrix': {'wiki_title': 'confusion matrix',
#    'ontology_terms': [{'term': 'confusion matrix', 'redirect': False}]},
#   'newton%27s_method': {'wiki_title': "newton's method",
#    'ontology_terms': [{'term': "newton's method", 'redirect': False}]},
#   'association_rule_learning#eclat_algorithm': {'wiki_title': 'association rule learning',
#    'ontology_terms': [{'term': 'eclat algorithm', 'redirect': True}]},
#   'topic_model': {'wiki_title': 'topic model',
#    'ontology_terms': [{'term': 'topic modeling', 'redirect': True}]},
#   'boltzmann_machine': {'wiki_title': 'boltzmann machine',
#    'ontology_terms': [{'term': 'boltzmann machines', 'redirect': False}]},
#   'hierarchical_clustering': {'wiki_title': 'hierarchical clustering',
#    'ontology_terms': [{'term': 'hierarchical clustering', 'redirect': False}]},
#   'k-medians_clustering': {'wiki_title': 'k-medians clustering',
#    'ontology_terms': [{'term': 'k-medians', 'redirect': True}]},
#   'probably_approximately_correct_learning': {'wiki_title': 'probably approximately correct learning',
#    'ontology_terms': [{'term': 'probably approximately correct learning',
#      'redirect': False}]},
#   'neural_coding#sparse_coding': {'wiki_title': 'neural coding',
#    'ontology_terms': [{'term': 'sparse coding', 'redirect': True}]},
#   'convolutional_neural_network': {'wiki_title': 'convolutional neural network',
#    'ontology_terms': [{'term': 'convolutional neural network',
#      'redirect': False}]},
#   'case-based_reasoning': {'wiki_title': 'case-based reasoning',
#    'ontology_terms': [{'term': 'case-based reasoning', 'redirect': False}]},
#   'concept_drift': {'wiki_title': 'concept drift',
#    'ontology_terms': [{'term': 'concept drift', 'redirect': False}]},
#   'gradient_boosting': {'wiki_title': 'gradient boosting',
#    'ontology_terms': [{'term': 'gradient boosting', 'redirect': False}]},
#   'stochastic_gradient_descent#adagrad': {'wiki_title': 'stochastic gradient descent',
#    'ontology_terms': [{'term': 'adagrad', 'redirect': False}]},
#   'synthetic_data': {'wiki_title': 'synthetic data',
#    'ontology_terms': [{'term': 'synthetic data', 'redirect': False}]},
#   'bayesian_network': {'wiki_title': 'bayesian network',
#    'ontology_terms': [{'term': 'bayesian network', 'redirect': False},
#     {'term': 'bayesian belief network', 'redirect': True}]},
#   'mean_squared_error': {'wiki_title': 'mean squared error',
#    'ontology_terms': [{'term': 'mean squared error', 'redirect': True}]},
#   'principal_component_analysis': {'wiki_title': 'principal component analysis',
#    'ontology_terms': [{'term': 'principal component analysis',
#      'redirect': False}]},
#   'hidden_markov_model': {'wiki_title': 'hidden markov model',
#    'ontology_terms': [{'term': 'hidden markov models', 'redirect': True}]},
#   'named-entity_recognition': {'wiki_title': 'named-entity recognition',
#    'ontology_terms': [{'term': 'named-entity recognition',
#      'redirect': False}]},
#   'optical_flow': {'wiki_title': 'optical flow',
#    'ontology_terms': [{'term': 'optical flow', 'redirect': False}]},
#   'autoencoder': {'wiki_title': 'autoencoder',
#    'ontology_terms': [{'term': 'autoencoder', 'redirect': False}]},
#   'association_rule_learning': {'wiki_title': 'association rule learning',
#    'ontology_terms': [{'term': 'association rule learning',
#      'redirect': False}]},
#   'ripple-down_rules': {'wiki_title': 'ripple-down rules',
#    'ontology_terms': [{'term': 'ripple down rules', 'redirect': True}]},
#   'regression_analysis': {'wiki_title': 'regression analysis',
#    'ontology_terms': [{'term': 'regression analysis', 'redirect': False}]},
#   'convolutional_neural_network#pooling_layer': {'wiki_title': 'convolutional neural network',
#    'ontology_terms': [{'term': 'max pooling', 'redirect': True}]},
#   'stochastic_gradient_descent': {'wiki_title': 'stochastic gradient descent',
#    'ontology_terms': [{'term': 'stochastic gradient descent',
#      'redirect': False}]},
#   'kriging': {'wiki_title': 'kriging',
#    'ontology_terms': [{'term': 'gaussian process regression',
#      'redirect': True}]},
#   'gradient_boosting#gradient_tree_boosting': {'wiki_title': 'gradient boosting',
#    'ontology_terms': [{'term': 'gradient boosted decision tree',
#      'redirect': True}]},
#   'multiclass_classification': {'wiki_title': 'multiclass classification',
#    'ontology_terms': [{'term': 'multi-class classification',
#      'redirect': False}]},
#   'transfer_learning': {'wiki_title': 'transfer learning',
#    'ontology_terms': [{'term': 'transfer learning', 'redirect': False}]},
#   'binary_classification': {'wiki_title': 'binary classification',
#    'ontology_terms': [{'term': 'binary classification', 'redirect': False},
#     {'term': 'binary classifier', 'redirect': True}]},
#   'multivariate_adaptive_regression_spline': {'wiki_title': 'multivariate adaptive regression spline',
#    'ontology_terms': [{'term': 'multivariate adaptive regression splines',
#      'redirect': False}]},
#   'scaling_(geometry)': {'wiki_title': 'scaling (geometry)',
#    'ontology_terms': [{'term': 'scaling', 'redirect': False}]},
#   'hierarchical_classification': {'wiki_title': 'hierarchical classification',
#    'ontology_terms': [{'term': 'hierarchical classifier', 'redirect': True}]},
#   'hyperbolic_functions': {'wiki_title': 'hyperbolic functions',
#    'ontology_terms': [{'term': 'tanh', 'redirect': True}]},
#   'root_mean_square_deviation': {'wiki_title': 'root mean square deviation',
#    'ontology_terms': [{'term': 'root mean squared error', 'redirect': True}]},
#   'random_search': {'wiki_title': 'random search',
#    'ontology_terms': [{'term': 'random search', 'redirect': False}]},
#   'overfitting': {'wiki_title': 'overfitting',
#    'ontology_terms': [{'term': 'overfitting', 'redirect': False}]},
#   'self-supervised_learning': {'wiki_title': 'self-supervised learning',
#    'ontology_terms': [{'term': 'self-supervised learning',
#      'redirect': False}]},
#   'long_short-term_memory': {'wiki_title': 'long short-term memory',
#    'ontology_terms': [{'term': 'long short-term memory', 'redirect': False}]},
#   'unsupervised_learning': {'wiki_title': 'unsupervised learning',
#    'ontology_terms': [{'term': 'unsupervised learning', 'redirect': False}]},
#   'conditional_random_field': {'wiki_title': 'conditional random field',
#    'ontology_terms': [{'term': 'conditional random field',
#      'redirect': False}]},
#   'normal_distribution': {'wiki_title': 'normal distribution',
#    'ontology_terms': [{'term': 'normal distribution', 'redirect': False}]},
#   'linear_discriminant_analysis': {'wiki_title': 'linear discriminant analysis',
#    'ontology_terms': [{'term': 'linear discriminant analysis',
#      'redirect': False}]},
#   'temporal_difference_learning': {'wiki_title': 'temporal difference learning',
#    'ontology_terms': [{'term': 'temporal difference learning',
#      'redirect': False}]},
#   'ensemble_learning': {'wiki_title': 'ensemble learning',
#    'ontology_terms': [{'term': 'ensemble methods', 'redirect': True},
#     {'term': 'ensemble learning', 'redirect': False}]},
#   'level_of_measurement#ordinal_scale': {'wiki_title': 'level of measurement',
#    'ontology_terms': [{'term': 'ordinal classification', 'redirect': True}]},
#   'standardization': {'wiki_title': 'standardization',
#    'ontology_terms': [{'term': 'standardization', 'redirect': False}]},
#   'large_language_model': {'wiki_title': 'large language model',
#    'ontology_terms': [{'term': 'large language models', 'redirect': False}]},
#   'activation_function': {'wiki_title': 'activation function',
#    'ontology_terms': [{'term': 'activation functions', 'redirect': False}]},
#   'bayesian_statistics': {'wiki_title': 'bayesian statistics',
#    'ontology_terms': [{'term': 'bayesian statistics', 'redirect': False}]},
#   'logistic_model_tree': {'wiki_title': 'logistic model tree',
#    'ontology_terms': [{'term': 'logistic model tree', 'redirect': False}]},
#   'supervised_learning': {'wiki_title': 'supervised learning',
#    'ontology_terms': [{'term': 'supervised learning', 'redirect': False}]},
#   'constraint_(mathematics)': {'wiki_title': 'constraint (mathematics)',
#    'ontology_terms': [{'term': 'constraints', 'redirect': False}]},
#   'multidimensional_scaling': {'wiki_title': 'multidimensional scaling',
#    'ontology_terms': [{'term': 'multi-dimensional scaling',
#      'redirect': False}]},
#   'batch_normalization': {'wiki_title': 'batch normalization',
#    'ontology_terms': [{'term': 'batch normalization', 'redirect': False}]},
#   'single-linkage_clustering': {'wiki_title': 'single-linkage clustering',
#    'ontology_terms': [{'term': 'single-linkage clustering',
#      'redirect': False}]},
#   'deep_learning': {'wiki_title': 'deep learning',
#    'ontology_terms': [{'term': 'deep learning', 'redirect': False}]},
#   'metadata': {'wiki_title': 'metadata',
#    'ontology_terms': [{'term': 'metadata', 'redirect': False}]},
#   'feedforward_neural_network': {'wiki_title': 'feedforward neural network',
#    'ontology_terms': [{'term': 'feedforward neural network',
#      'redirect': False}]},
#   'analogical_modeling': {'wiki_title': 'analogical modeling',
#    'ontology_terms': [{'term': 'analogical modeling', 'redirect': False}]},
#   'learning_rate': {'wiki_title': 'learning rate',
#    'ontology_terms': [{'term': 'learning rate', 'redirect': False}]},
#   'convolutional_neural_network#pooling_layers': {'wiki_title': 'convolutional neural network',
#    'ontology_terms': [{'term': 'pooling layers', 'redirect': False}]},
#   'precision_(computer_science)': {'wiki_title': 'precision (computer science)',
#    'ontology_terms': [{'term': 'precision', 'redirect': False}]},
#   'edge_detection': {'wiki_title': 'edge detection',
#    'ontology_terms': [{'term': 'edge detection', 'redirect': False}]},
#   'group_method_of_data_handling': {'wiki_title': 'group method of data handling',
#    'ontology_terms': [{'term': 'group method of data handling',
#      'redirect': False}]},
#   'logistic_regression': {'wiki_title': 'logistic regression',
#    'ontology_terms': [{'term': 'logistic regression', 'redirect': False}]},
#   'speech_recognition': {'wiki_title': 'speech recognition',
#    'ontology_terms': [{'term': 'speech recognition', 'redirect': False}]},
#   'q-function': {'wiki_title': 'q-function',
#    'ontology_terms': [{'term': 'q-function', 'redirect': False}]},
#   'dbscan': {'wiki_title': 'dbscan',
#    'ontology_terms': [{'term': 'dbscan', 'redirect': True}]},
#   'transduction_(machine_learning)': {'wiki_title': 'transduction (machine learning)',
#    'ontology_terms': [{'term': 'transduction', 'redirect': False}]},
#   'inceptionv3': {'wiki_title': 'inceptionv3',
#    'ontology_terms': [{'term': 'inception', 'redirect': False}]},
#   'linear_classifier': {'wiki_title': 'linear classifier',
#    'ontology_terms': [{'term': 'linear classifier', 'redirect': False}]},
#   'feature_engineering': {'wiki_title': 'feature engineering',
#    'ontology_terms': [{'term': 'feature extraction', 'redirect': True},
#     {'term': 'feature engineering', 'redirect': False}]},
#   'time_series': {'wiki_title': 'time series',
#    'ontology_terms': [{'term': 'time series prediction', 'redirect': True}]},
#   'naive_bayes_classifier': {'wiki_title': 'naive bayes classifier',
#    'ontology_terms': [{'term': 'naive bayes', 'redirect': True}]},
#   'word2vec': {'wiki_title': 'word2vec',
#    'ontology_terms': [{'term': 'word2vec', 'redirect': False}]},
#   'learning_rate#adaptive_learning_rate': {'wiki_title': 'learning rate',
#    'ontology_terms': [{'term': 'adaptive learning rate', 'redirect': True}]},
#   'ensemble_averaging_(machine_learning)': {'wiki_title': 'ensemble averaging (machine learning)',
#    'ontology_terms': [{'term': 'ensemble averaging', 'redirect': True}]},
#   'elastic_map': {'wiki_title': 'elastic map',
#    'ontology_terms': [{'term': 'elastic net', 'redirect': True}]},
#   'machine_translation': {'wiki_title': 'machine translation',
#    'ontology_terms': [{'term': 'machine translation', 'redirect': False}]},
#   'ridge_regression#tikhonov_regularization': {'wiki_title': 'ridge regression',
#    'ontology_terms': [{'term': 'weight decay', 'redirect': True}]},
#   'sampling_(statistics)': {'wiki_title': 'sampling (statistics)',
#    'ontology_terms': [{'term': 'sampling', 'redirect': False}]},
#   'weak_supervision': {'wiki_title': 'weak supervision',
#    'ontology_terms': [{'term': 'semi-supervised learning', 'redirect': True}]},
#   'binary_decoder': {'wiki_title': 'binary decoder',
#    'ontology_terms': [{'term': 'decoder', 'redirect': False}]},
#   'support_vector_machine': {'wiki_title': 'support vector machine',
#    'ontology_terms': [{'term': 'support vector machines', 'redirect': True}]},
#   'neural_network_(machine_learning)': {'wiki_title': 'neural network (machine learning)',
#    'ontology_terms': [{'term': 'artificial neural network',
#      'redirect': True}]},
#   'prompt_engineering': {'wiki_title': 'prompt engineering',
#    'ontology_terms': [{'term': 'prompt engineering', 'redirect': False}]},
#   'curriculum_learning': {'wiki_title': 'curriculum learning',
#    'ontology_terms': [{'term': 'curriculum learning', 'redirect': False}]},
#   'ordinary_least_squares': {'wiki_title': 'ordinary least squares',
#    'ontology_terms': [{'term': 'ordinary least squares regression',
#      'redirect': True}]},
#   'prompt_engineering#chain-of-thought': {'wiki_title': 'prompt engineering',
#    'ontology_terms': [{'term': 'chain-of-thought prompting',
#      'redirect': True}]},
#   'stepwise_regression': {'wiki_title': 'stepwise regression',
#    'ontology_terms': [{'term': 'stepwise regression', 'redirect': False}]},
#   'multi-task_learning': {'wiki_title': 'multi-task learning',
#    'ontology_terms': [{'term': 'multi-task learning', 'redirect': False}]},
#   'neural_architecture_search': {'wiki_title': 'neural architecture search',
#    'ontology_terms': [{'term': 'neural architecture search',
#      'redirect': False}]},
#   'perplexity': {'wiki_title': 'perplexity',
#    'ontology_terms': [{'term': 'perplexity', 'redirect': False}]},
#   'projection_pursuit': {'wiki_title': 'projection pursuit',
#    'ontology_terms': [{'term': 'projection pursuit', 'redirect': False}]},
#   'deep_belief_network': {'wiki_title': 'deep belief network',
#    'ontology_terms': [{'term': 'deep belief networks', 'redirect': False}]},
#   'data_cleansing': {'wiki_title': 'data cleansing',
#    'ontology_terms': [{'term': 'data cleaning', 'redirect': True}]},
#   'partial_least_squares_regression': {'wiki_title': 'partial least squares regression',
#    'ontology_terms': [{'term': 'partial least squares regression',
#      'redirect': False}]},
#   'large_language_model#prompt_engineering,_attention_mechanism,_and_context_window': {'wiki_title': 'large language model',
#    'ontology_terms': [{'term': 'context window', 'redirect': True}]},
#   'stochastic_gradient_descent#rmsprop': {'wiki_title': 'stochastic gradient descent',
#    'ontology_terms': [{'term': 'rmsprop', 'redirect': False}]},
#   'vanishing_gradient_problem': {'wiki_title': 'vanishing gradient problem',
#    'ontology_terms': [{'term': 'vanishing gradient problem',
#      'redirect': False}]},
#   'boosting_(machine_learning)': {'wiki_title': 'boosting (machine learning)',
#    'ontology_terms': [{'term': 'boosting', 'redirect': False}]},
#   'dimensionality_reduction': {'wiki_title': 'dimensionality reduction',
#    'ontology_terms': [{'term': 'dimensionality reduction',
#      'redirect': False}]},
#   'false_positives_and_false_negatives#true_negative': {'wiki_title': 'false positives and false negatives',
#    'ontology_terms': [{'term': 'true negative', 'redirect': True}]},
#   'phi_coefficient': {'wiki_title': 'phi coefficient',
#    'ontology_terms': [{'term': 'matthews correlation coefficient',
#      'redirect': True}]},
#   'reinforcement_learning': {'wiki_title': 'reinforcement learning',
#    'ontology_terms': [{'term': 'reinforcement learning', 'redirect': False}]},
#   'pattern_recognition': {'wiki_title': 'pattern recognition',
#    'ontology_terms': [{'term': 'pattern recognition', 'redirect': False}]},
#   'mean_reciprocal_rank': {'wiki_title': 'mean reciprocal rank',
#    'ontology_terms': [{'term': 'mean reciprocal rank', 'redirect': False}]},
#   'quantization_(signal_processing)': {'wiki_title': 'quantization (signal processing)',
#    'ontology_terms': [{'term': 'quantization', 'redirect': False}]},
#   'generative_model': {'wiki_title': 'generative model',
#    'ontology_terms': [{'term': 'generative models', 'redirect': False}]},
#   'false_positives_and_false_negatives#false_negative_error': {'wiki_title': 'false positives and false negatives',
#    'ontology_terms': [{'term': 'false negative', 'redirect': True}]},
#   'bhattacharyya_distance': {'wiki_title': 'bhattacharyya distance',
#    'ontology_terms': [{'term': 'bhattacharyya distance', 'redirect': False}]},
#   'cohen%27s_kappa': {'wiki_title': "cohen's kappa",
#    'ontology_terms': [{'term': "cohen's kappa", 'redirect': False}]},
#   'stochastic_gradient_descent#adam': {'wiki_title': 'stochastic gradient descent',
#    'ontology_terms': [{'term': 'adam', 'redirect': False}]},
#   'jaccard_index': {'wiki_title': 'jaccard index',
#    'ontology_terms': [{'term': 'jaccard index', 'redirect': False}]},
#   'independent_component_analysis': {'wiki_title': 'independent component analysis',
#    'ontology_terms': [{'term': 'independent component analysis',
#      'redirect': False}]},
#   'huber_loss': {'wiki_title': 'huber loss',
#    'ontology_terms': [{'term': 'huber loss', 'redirect': False}]},
#   'expectation%e2%80%93maximization_algorithm': {'wiki_title': 'expectation–maximization algorithm',
#    'ontology_terms': [{'term': 'expectation-maximization algorithm',
#      'redirect': True}]},
#   'mean_shift': {'wiki_title': 'mean shift',
#    'ontology_terms': [{'term': 'mean-shift', 'redirect': False}]},
#   'data_integration': {'wiki_title': 'data integration',
#    'ontology_terms': [{'term': 'data integration', 'redirect': False}]},
#   'softmax_function': {'wiki_title': 'softmax function',
#    'ontology_terms': [{'term': 'softmax', 'redirect': True}]},
#   'cross-validation_(statistics)#leave-one-out_cross-validation': {'wiki_title': 'cross-validation (statistics)',
#    'ontology_terms': [{'term': 'leave-one-out', 'redirect': True}]},
#   'recurrent_neural_network': {'wiki_title': 'recurrent neural network',
#    'ontology_terms': [{'term': 'recurrent neural network',
#      'redirect': False}]},
#   'reinforcement_learning_from_human_feedback': {'wiki_title': 'reinforcement learning from human feedback',
#    'ontology_terms': [{'term': 'reinforcement learning from human feedback',
#      'redirect': False}]},
#   'gated_recurrent_unit': {'wiki_title': 'gated recurrent unit',
#    'ontology_terms': [{'term': 'gated recurrent unit', 'redirect': False}]},
#   'factor_analysis': {'wiki_title': 'factor analysis',
#    'ontology_terms': [{'term': 'factor analysis', 'redirect': False}]},
#   'self-organizing_map': {'wiki_title': 'self-organizing map',
#    'ontology_terms': [{'term': 'self-organizing map', 'redirect': False}]},
#   'loss_function': {'wiki_title': 'loss function',
#    'ontology_terms': [{'term': 'loss function', 'redirect': False}]},
#   'fuzzy_clustering': {'wiki_title': 'fuzzy clustering',
#    'ontology_terms': [{'term': 'fuzzy clustering', 'redirect': False}]},
#   'learning_automaton': {'wiki_title': 'learning automaton',
#    'ontology_terms': [{'term': 'learning automata', 'redirect': True}]},
#   'k-nearest_neighbors_algorithm': {'wiki_title': 'k-nearest neighbors algorithm',
#    'ontology_terms': [{'term': 'k-nearest neighbor', 'redirect': True}]},
#   'principal_component_regression': {'wiki_title': 'principal component regression',
#    'ontology_terms': [{'term': 'principal component regression',
#      'redirect': False}]},
#   'conceptual_clustering': {'wiki_title': 'conceptual clustering',
#    'ontology_terms': [{'term': 'conceptual clustering', 'redirect': False}]},
#   'random_forest': {'wiki_title': 'random forest',
#    'ontology_terms': [{'term': 'random forest', 'redirect': False}]},
#   'inductive_bias': {'wiki_title': 'inductive bias',
#    'ontology_terms': [{'term': 'inductive bias', 'redirect': False}]},
#   'active_learning_(machine_learning)': {'wiki_title': 'active learning (machine learning)',
#    'ontology_terms': [{'term': 'active learning', 'redirect': False}]},
#   'hierarchical_hidden_markov_model': {'wiki_title': 'hierarchical hidden markov model',
#    'ontology_terms': [{'term': 'hierarchical hidden markov model',
#      'redirect': True}]},
#   'bootstrap_aggregating': {'wiki_title': 'bootstrap aggregating',
#    'ontology_terms': [{'term': 'bootstrap aggregating', 'redirect': False}]},
#   'canonical_correlation': {'wiki_title': 'canonical correlation',
#    'ontology_terms': [{'term': 'canonical correlation analysis',
#      'redirect': True}]},
#   'lazy_learning': {'wiki_title': 'lazy learning',
#    'ontology_terms': [{'term': 'lazy learning', 'redirect': False}]},
#   'local_outlier_factor': {'wiki_title': 'local outlier factor',
#    'ontology_terms': [{'term': 'local outlier factor', 'redirect': False}]},
#   'quadratic_classifier': {'wiki_title': 'quadratic classifier',
#    'ontology_terms': [{'term': 'quadratic classifiers', 'redirect': False}]},
#   'learning_vector_quantization': {'wiki_title': 'learning vector quantization',
#    'ontology_terms': [{'term': 'learning vector quantization',
#      'redirect': False}]},
#   'chi-squared_distribution': {'wiki_title': 'chi-squared distribution',
#    'ontology_terms': [{'term': 'chi-squared', 'redirect': False}]},
#   'bellman_equation': {'wiki_title': 'bellman equation',
#    'ontology_terms': [{'term': 'bellman equation', 'redirect': False}]},
#   'graph_neural_network': {'wiki_title': 'graph neural network',
#    'ontology_terms': [{'term': 'graph neural networks', 'redirect': False}]},
#   'document_classification': {'wiki_title': 'document classification',
#    'ontology_terms': [{'term': 'text classification', 'redirect': False}]},
#   'f-score': {'wiki_title': 'f-score',
#    'ontology_terms': [{'term': 'f1 score', 'redirect': True}]},
#   'spectral_clustering': {'wiki_title': 'spectral clustering',
#    'ontology_terms': [{'term': 'spectral clustering', 'redirect': False}]},
#   'birch': {'wiki_title': 'birch',
#    'ontology_terms': [{'term': 'birch', 'redirect': False}]},
#   'instance-based_learning': {'wiki_title': 'instance-based learning',
#    'ontology_terms': [{'term': 'instance-based learning', 'redirect': False}]},
#   'averaged_one-dependence_estimators': {'wiki_title': 'averaged one-dependence estimators',
#    'ontology_terms': [{'term': 'averaged one-dependence estimators',
#      'redirect': False}]},
#   'feature_selection': {'wiki_title': 'feature selection',
#    'ontology_terms': [{'term': 'feature selection', 'redirect': False}]},
#   'data_augmentation': {'wiki_title': 'data augmentation',
#    'ontology_terms': [{'term': 'data augmentation', 'redirect': False}]},
#   'analysis_of_variance': {'wiki_title': 'analysis of variance',
#    'ontology_terms': [{'term': 'anova', 'redirect': True}]},
#   'gradient_descent': {'wiki_title': 'gradient descent',
#    'ontology_terms': [{'term': 'gradient descent', 'redirect': False},
#     {'term': 'gradient descent algorithms', 'redirect': False}]},
#   'ridge_regression': {'wiki_title': 'ridge regression',
#    'ontology_terms': [{'term': 'ridge regression', 'redirect': False}]},
#   'latent_dirichlet_allocation': {'wiki_title': 'latent dirichlet allocation',
#    'ontology_terms': [{'term': 'latent dirichlet allocation',
#      'redirect': True}]},
#   'anomaly_detection': {'wiki_title': 'anomaly detection',
#    'ontology_terms': [{'term': 'anomaly detection', 'redirect': False}]},
#   'adaboost': {'wiki_title': 'adaboost',
#    'ontology_terms': [{'term': 'adaboost', 'redirect': True}]},
#   'sammon_mapping': {'wiki_title': 'sammon mapping',
#    'ontology_terms': [{'term': 'sammon mapping', 'redirect': False}]},
#   'noise_reduction': {'wiki_title': 'noise reduction',
#    'ontology_terms': [{'term': 'noise reduction', 'redirect': False}]},
#   'decision_tree_learning': {'wiki_title': 'decision tree learning',
#    'ontology_terms': [{'term': 'classification metrics', 'redirect': False}]},
#   'co-training': {'wiki_title': 'co-training',
#    'ontology_terms': [{'term': 'co-training', 'redirect': False}]},
#   'neural_style_transfer': {'wiki_title': 'neural style transfer',
#    'ontology_terms': [{'term': 'style transfer', 'redirect': True}]},
#   'decision_tree_pruning': {'wiki_title': 'decision tree pruning',
#    'ontology_terms': [{'term': 'pruning', 'redirect': True}]},
#   'linear_regression': {'wiki_title': 'linear regression',
#    'ontology_terms': [{'term': 'linear regression', 'redirect': False}]},
#   'softmax_function#temperature': {'wiki_title': 'softmax function',
#    'ontology_terms': [{'term': 'temperature', 'redirect': True}]},
#   'residual_neural_network': {'wiki_title': 'residual neural network',
#    'ontology_terms': [{'term': 'resnet', 'redirect': False}]},
#   'spectral_centroid': {'wiki_title': 'spectral centroid',
#    'ontology_terms': [{'term': 'spectral centroid', 'redirect': False}]},
#   'pitch_shifting': {'wiki_title': 'pitch shifting',
#    'ontology_terms': [{'term': 'pitch shifting', 'redirect': False}]},
#   'knowledge_distillation': {'wiki_title': 'knowledge distillation',
#    'ontology_terms': [{'term': 'distillation', 'redirect': False}]},
#   'regular_expression': {'wiki_title': 'regular expression',
#    'ontology_terms': [{'term': 'regular expressions', 'redirect': False}]},
#   'shot_transition_detection': {'wiki_title': 'shot transition detection',
#    'ontology_terms': [{'term': 'shot boundary detection', 'redirect': False}]},
#   'meta-learning_(computer_science)': {'wiki_title': 'meta-learning (computer science)',
#    'ontology_terms': [{'term': 'meta-learning', 'redirect': False}]},
#   'resampling_(statistics)': {'wiki_title': 'resampling (statistics)',
#    'ontology_terms': [{'term': 'resampling', 'redirect': False}]},
#   'association_rule_learning#fp-growth_algorithm': {'wiki_title': 'association rule learning',
#    'ontology_terms': [{'term': 'fp-growth algorithm', 'redirect': False}]},
#   'vector_database': {'wiki_title': 'vector database',
#    'ontology_terms': [{'term': 'vector databases', 'redirect': False}]},
#   'mahalanobis_distance': {'wiki_title': 'mahalanobis distance',
#    'ontology_terms': [{'term': 'mahalanobis distance', 'redirect': False}]},
#   'stop_word': {'wiki_title': 'stop word',
#    'ontology_terms': [{'term': 'stop word removal', 'redirect': False}]},
#   'mean_absolute_error': {'wiki_title': 'mean absolute error',
#    'ontology_terms': [{'term': 'mean absolute error', 'redirect': False}]},
#   'n-gram': {'wiki_title': 'n-gram',
#    'ontology_terms': [{'term': 'character n-grams', 'redirect': False}]},
#   'word_n-gram_language_model': {'wiki_title': 'word n-gram language model',
#    'ontology_terms': [{'term': 'word n-grams', 'redirect': False}]},
#   'imputation_(statistics)#regression': {'wiki_title': 'imputation (statistics)',
#    'ontology_terms': [{'term': 'regression imputation', 'redirect': False}]},
#   'data_transformation_(computing)': {'wiki_title': 'data transformation (computing)',
#    'ontology_terms': [{'term': 'feature transformation', 'redirect': False},
#     {'term': 'data transformation', 'redirect': False}]},
#   'oversampling_and_undersampling_in_data_analysis#random_undersampling': {'wiki_title': 'oversampling and undersampling in data analysis',
#    'ontology_terms': [{'term': 'random undersampling', 'redirect': False}]},
#   'oversampling_and_undersampling_in_data_analysis#adasyn': {'wiki_title': 'oversampling and undersampling in data analysis',
#    'ontology_terms': [{'term': 'adasyn (adaptive synthetic)',
#      'redirect': False}]},
#   'inception_score': {'wiki_title': 'inception score',
#    'ontology_terms': [{'term': 'inception score', 'redirect': False}]},
#   'bleu': {'wiki_title': 'bleu',
#    'ontology_terms': [{'term': 'bleu score', 'redirect': False}]},
#   'fréchet_inception_distance': {'wiki_title': 'fréchet inception distance',
#    'ontology_terms': [{'term': 'fréchet inception distance',
#      'redirect': False}]},
#   'data_preparation': {'wiki_title': 'data preparation',
#    'ontology_terms': [{'term': 'data preparation', 'redirect': False}]},
#   'loss_functions_for_classification#logistic_loss': {'wiki_title': 'loss functions for classification',
#    'ontology_terms': [{'term': 'log loss', 'redirect': False}]},
#   'convolutional_neural_network#convolutional_layer': {'wiki_title': 'convolutional neural network',
#    'ontology_terms': [{'term': 'convolutional layer', 'redirect': False}]},
#   'discrete_uniform_distribution': {'wiki_title': 'discrete uniform distribution',
#    'ontology_terms': [{'term': 'uniform distribution', 'redirect': False}]},
#   'hyperparameter_optimization': {'wiki_title': 'hyperparameter optimization',
#    'ontology_terms': [{'term': 'hyperparameter selection',
#      'redirect': False}]},
#   'data_retrieval': {'wiki_title': 'data retrieval',
#    'ontology_terms': [{'term': 'data retrieval', 'redirect': False}]},
#   'bag-of-words_model': {'wiki_title': 'bag-of-words model',
#    'ontology_terms': [{'term': 'bag of words', 'redirect': False}]},
#   'evaluation_measures_(information_retrieval)': {'wiki_title': 'evaluation measures (information retrieval)',
#    'ontology_terms': [{'term': 'information retrieval metrics',
#      'redirect': False}]},
#   'data_deduplication': {'wiki_title': 'data deduplication',
#    'ontology_terms': [{'term': 'deduplication', 'redirect': False}]},
#   'gaussian_noise': {'wiki_title': 'gaussian noise',
#    'ontology_terms': [{'term': 'gaussian noise', 'redirect': False}]},
#   'transformer_(deep_learning_architecture)#encoder-decoder_(overview)': {'wiki_title': 'transformer (deep learning architecture)',
#    'ontology_terms': [{'term': 'encoder-decoder', 'redirect': False}]},
#   'vanishing_gradient_problem#weight_initialization': {'wiki_title': 'vanishing gradient problem',
#    'ontology_terms': [{'term': 'weight initialization', 'redirect': False}]},
#   'evidence_lower_bound': {'wiki_title': 'evidence lower bound',
#    'ontology_terms': [{'term': 'variational lower bound', 'redirect': False}]},
#   'rectifier_(neural_networks)': {'wiki_title': 'rectifier (neural networks)',
#    'ontology_terms': [{'term': 'rectified linear unit (relu)',
#      'redirect': False}]},
#   'stemming': {'wiki_title': 'stemming',
#    'ontology_terms': [{'term': 'stemming', 'redirect': False}]},
#   'intelligent_agent': {'wiki_title': 'intelligent agent',
#    'ontology_terms': [{'term': 'llm agents', 'redirect': False}]},
#   'object_detection': {'wiki_title': 'object detection',
#    'ontology_terms': [{'term': 'object detection', 'redirect': False}]},
#   'data_reduction': {'wiki_title': 'data reduction',
#    'ontology_terms': [{'term': 'data reduction', 'redirect': False}]},
#   'canonical_form#computing': {'wiki_title': 'canonical form',
#    'ontology_terms': [{'term': 'normalization', 'redirect': False}]},
#   'silhouette_(clustering)': {'wiki_title': 'silhouette (clustering)',
#    'ontology_terms': [{'term': 'silhouette score', 'redirect': False}]},
#   'hinge_loss': {'wiki_title': 'hinge loss',
#    'ontology_terms': [{'term': 'hinge loss', 'redirect': False}]},
#   'dilution_(neural_networks)#dropout': {'wiki_title': 'dilution (neural networks)',
#    'ontology_terms': [{'term': 'dropout', 'redirect': False}]},
#   'elmo': {'wiki_title': 'elmo',
#    'ontology_terms': [{'term': 'elmo (embeddings from language model)',
#      'redirect': False}]},
#   'brier_score': {'wiki_title': 'brier score',
#    'ontology_terms': [{'term': 'brier score', 'redirect': False}]},
#   'lasso_(statistics)': {'wiki_title': 'lasso (statistics)',
#    'ontology_terms': [{'term': 'least absolute shrinkage and selection operator (lasso)',
#      'redirect': False}]},
#   'hyperparameter_optimization#grid_search': {'wiki_title': 'hyperparameter optimization',
#    'ontology_terms': [{'term': 'grid search', 'redirect': False}]},
#   'oversampling_and_undersampling_in_data_analysis#smote': {'wiki_title': 'oversampling and undersampling in data analysis',
#    'ontology_terms': [{'term': 'smote (synthetic minority over-sampling technique)',
#      'redirect': False}]},
#   'lemmatization': {'wiki_title': 'lemmatization',
#    'ontology_terms': [{'term': 'lemmatization', 'redirect': False}]},
#   'early_stopping': {'wiki_title': 'early stopping',
#    'ontology_terms': [{'term': 'early stopping', 'redirect': False}]},
#   'gini_coefficient': {'wiki_title': 'gini coefficient',
#    'ontology_terms': [{'term': 'gini coefficient', 'redirect': False}]},
#   'histogram_of_oriented_gradients': {'wiki_title': 'histogram of oriented gradients',
#    'ontology_terms': [{'term': 'hog (histogram of oriented gradients)',
#      'redirect': False}]},
#   'one-hot': {'wiki_title': 'one-hot',
#    'ontology_terms': [{'term': 'one-hot encoding', 'redirect': False}]},
#   'attention_(machine_learning)': {'wiki_title': 'attention (machine learning)',
#    'ontology_terms': [{'term': 'self-attention layer', 'redirect': False}]},
#   'hellinger_distance': {'wiki_title': 'hellinger distance',
#    'ontology_terms': [{'term': 'hellinger distance', 'redirect': False}]},
#   'exponential_decay': {'wiki_title': 'exponential decay',
#    'ontology_terms': [{'term': 'exponential decay', 'redirect': False}]},
#   'coefficient_of_determination#adjusted_r2': {'wiki_title': 'coefficient of determination',
#    'ontology_terms': [{'term': 'adjusted r-squared', 'redirect': False}]},
#   'search_engine_indexing': {'wiki_title': 'search engine indexing',
#    'ontology_terms': [{'term': 'data indexing', 'redirect': False}]},
#   'chunk_(information)': {'wiki_title': 'chunk (information)',
#    'ontology_terms': [{'term': 'data chunking', 'redirect': False}]},
#   'statistics#methods': {'wiki_title': 'statistics',
#    'ontology_terms': [{'term': 'statistical methods', 'redirect': False}]},
#   'chi-squared_test': {'wiki_title': 'chi-squared test',
#    'ontology_terms': [{'term': 'chi-squared test', 'redirect': False}]},
#   'meteoroid#meteors': {'wiki_title': 'meteoroid',
#    'ontology_terms': [{'term': 'meteor score', 'redirect': True}]},
#   'lasso_(statistics)#fused_lasso': {'wiki_title': 'lasso (statistics)',
#    'ontology_terms': [{'term': 'fused lasso', 'redirect': False}]},
#   'imputation_(statistics)': {'wiki_title': 'imputation (statistics)',
#    'ontology_terms': [{'term': 'imputation', 'redirect': False}]},
#   't-distributed_stochastic_neighbor_embedding': {'wiki_title': 't-distributed stochastic neighbor embedding',
#    'ontology_terms': [{'term': 't-distributed stochastic neighbor embedding (t-sne)',
#      'redirect': False}]},
#   'transpose': {'wiki_title': 'transpose',
#    'ontology_terms': [{'term': 'transposing', 'redirect': False}]}},
#  'ontology_terms': {}}

# %% [markdown]
# ## Save files

# %%
if kb_lookup:

    relative_path = '../../siads_capstone/'
    
    absolute_path = os.path.abspath(relative_path)

    file_name = "kb_lookup.json"
    
    file_path = os.path.join(absolute_path, file_name)

    with open(file_path, 'w') as f:
        json.dump(kb_lookup, f, indent=4)
    
    print(f"kb_lookup has been saved as '{file_name}' in the following directory:")
    print(absolute_path)
    
    print(f"Number of wiki_paths in kb_lookup: {len(kb_lookup['wiki_paths'])}")
    print(f"Number of ontology_terms in kb_lookup: {len(kb_lookup['ontology_terms'])}")
else:
    print("kb_lookup is empty. No file was created.")
# Out:
# kb_lookup has been saved as 'kb_lookup.json' in the following directory:
# /home/sagemaker-user/siads_capstone
# Number of wiki_paths in kb_lookup: 258
# Number of ontology_terms in kb_lookup: 0

# %%
file_path = '../../siads_capstone/kb_lookup.json'

with open(file_path, 'r') as f:
    kb_lookup = json.load(f)

# Check entries
random_keys = random.sample(list(kb_lookup['wiki_paths'].keys()), 5)

for i, key in enumerate(random_keys, 1):
    value = kb_lookup['wiki_paths'][key]
    print(f"\n{i}. Wiki path: {key}")
    print(f"   Title: {value['wiki_title']}")
    print("   Ontology terms:")
    for term in value['ontology_terms']:
        print(f"     - {term['term']} (Redirect: {term['redirect']})")
# Out:
# 1. Wiki path: binary_decoder
#    Title: binary decoder
#    Ontology terms:
#      - decoder (Redirect: False)
#
# 2. Wiki path: bleu
#    Title: bleu
#    Ontology terms:
#      - bleu score (Redirect: False)
#
# 3. Wiki path: newton%27s_method
#    Title: newton's method
#    Ontology terms:
#      - newton's method (Redirect: False)
#
# 4. Wiki path: data_cleansing
#    Title: data cleansing
#    Ontology terms:
#      - data cleaning (Redirect: True)
#
# 5. Wiki path: hellinger_distance
#    Title: hellinger distance
#    Ontology terms:
#      - hellinger distance (Redirect: False)

# %%
for wiki_path, data in kb_lookup['wiki_paths'].items():
    if len(data['ontology_terms']) > 1:
        print(f"Wiki Path: {wiki_path}")
        print(f"Wiki Title: {data['wiki_title']}")
        print("Ontology Terms:")
        for term in data['ontology_terms']:
            print(f"  - {term['term']} (Redirect: {term['redirect']})")
        print("-" * 50)
# Out:
# Wiki Path: least-angle_regression
# Wiki Title: least-angle regression
# Ontology Terms:
#   - least-angle regression (Redirect: False)
#   - least angle regression (Redirect: False)
# --------------------------------------------------
# Wiki Path: word_embedding
# Wiki Title: word embedding
# Ontology Terms:
#   - embeddings (Redirect: False)
#   - word embeddings (Redirect: False)
# --------------------------------------------------
# Wiki Path: diffusion_model
# Wiki Title: diffusion model
# Ontology Terms:
#   - latent diffusion models (Redirect: False)
#   - diffusion models (Redirect: False)
# --------------------------------------------------
# Wiki Path: cross-validation_(statistics)
# Wiki Title: cross-validation (statistics)
# Ontology Terms:
#   - cross-validation (Redirect: False)
#   - k-fold (Redirect: False)
# --------------------------------------------------
# Wiki Path: bayesian_network
# Wiki Title: bayesian network
# Ontology Terms:
#   - bayesian network (Redirect: False)
#   - bayesian belief network (Redirect: True)
# --------------------------------------------------
# Wiki Path: binary_classification
# Wiki Title: binary classification
# Ontology Terms:
#   - binary classification (Redirect: False)
#   - binary classifier (Redirect: True)
# --------------------------------------------------
# Wiki Path: ensemble_learning
# Wiki Title: ensemble learning
# Ontology Terms:
#   - ensemble methods (Redirect: True)
#   - ensemble learning (Redirect: False)
# --------------------------------------------------
# Wiki Path: feature_engineering
# Wiki Title: feature engineering
# Ontology Terms:
#   - feature extraction (Redirect: True)
#   - feature engineering (Redirect: False)
# --------------------------------------------------
# Wiki Path: gradient_descent
# Wiki Title: gradient descent
# Ontology Terms:
#   - gradient descent (Redirect: False)
#   - gradient descent algorithms (Redirect: False)
# --------------------------------------------------
# Wiki Path: data_transformation_(computing)
# Wiki Title: data transformation (computing)
# Ontology Terms:
#   - feature transformation (Redirect: False)
#   - data transformation (Redirect: False)
# --------------------------------------------------
